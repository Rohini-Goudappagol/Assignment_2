# %% [markdown]
# 1. Build a simple webpage that displays text as shown in the below image.
#     - <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title></title>
# </head>
# <body>
#     <div>
#         <b>This text will be bolded</b> <br> <br>
#         <i>This text will be itallic</i> <br> <br>
#         <u>This text will be underlined</u> <br> <br>
#         <mark>This text will be highlighted</mark> <br> <br>
#         This is normal text <sup>This will be super scripted</sup> This is normal again <br> <br>
#         This is normal text <sub>This text will be subscripted</sub><br><br>
#         Normal Text <small>Small text</small><br><br>
#         <del>This text will be deleted</del>
#
#     </div>
# </body>
# </html>

# %% [markdown]
# 2. Build a simple webpage that helps users navigate different web development-related websites. Note: On clicking the hyperlink the web pages should open in a new tab. Below is a reference image.
#     - <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title></title>
# </head>
# <body>
#     <div>
#         <h1>Navigate Me:</h1>
#         Take me to <a href="https://pwskills.com/online-degree/?source=pwskills.com&position=nav_bar&buttonText=online_degree&page_ref=profile_page" target="_blank">PW Skills</a> to buy a course. <br><br>
#         Take me to <a href="https://developer.mozilla.org/en-US/docs/Web/HTML" target="_blank">MDN doc</a> to know more about Web Developement.<br><br>
#         Take me to <a href="https://pwskills.com/support/" target="_blank">PW Skills Lab</a> to practice live coding
#     </div>
# </body>
# </html>

# %% [markdown]
# 3. Build a simple blog web page with 3 pages home, web development, and web design. Each page must contain hyperlinks to other pages in the top, a heading of the page topic and a paragraph of information.For the home page you can add some information about yourself.
# # 1. Home.html
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Home - My Blog</title>
# </head>
# <body>
#     <header>
#         <nav>
#             <ul>
#                 <li><a href="index.html">Home</a></li>
#                 <li><a href="web-development.html">Web Development</a></li>
#                 <li><a href="web-design.html">Web Design</a></li>
#             </ul>
#         </nav>
#     </header>
#     <div>
#     <h1>Welcome to My Blog</h1>
#     <p>Hi! I'm Rohini, a passionate web developer and designer. This blog shares my thoughts on web development and design. Stay tuned for useful tips and resources!</p>
#     <div>
# </body>
# </html>
#
#
#
# # 2. Web-design.html
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Web Design - My Blog</title>
# </head>
# <body>
#     <header>
#         <nav>
#             <ul>
#                 <li><a href="index.html">Home</a></li>
#                 <li><a href="web-development.html">Web Development</a></li>
#                 <li><a href="web-design.html">Web Design</a></li>
#             </ul>
#         </nav>
#     </header>
#       <div>
#     <h1>Web Design</h1>
#     <p>Web design is about creating visually appealing and user-friendly websites. A good web designer focuses on layout, color schemes, typography, and ensuring that the website is responsive across different devices. I enjoy crafting designs that not only look good but also provide a seamless user experience.</p>
#     </div>
#
# </body>
# </html>
#
# # 3. Web-development.html
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Web Design - My Blog</title>
# </head>
# <body>
#     <header>
#         <nav>
#             <ul>
#                 <li><a href="index.html">Home</a></li>
#                 <li><a href="web-development.html">Web Development</a></li>
#                 <li><a href="web-design.html">Web Design</a></li>
#             </ul>
#         </nav>
#     </header>
#     <div>
#     <h1>Web Design</h1>
#     <p>Web design is about creating visually appealing and user-friendly websites. A good web designer focuses on layout, color schemes, typography, and ensuring that the website is responsive across different devices. I enjoy crafting designs that not only look good but also provide a seamless user experience.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# 4. Create an ordered list of HTML tags. Each list item must include the tag name and some information about the tag.
#
#     -
#     <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title></title>
# </head>
# <body>
#     <div>
#         <ol>
#             <li>
#                 <b>anchor tag : </b> The anchor tag in HTML is used to create a hyperlink on the webpage.
#             </li>
#             <br>
#             <li>
#                 <b>body tag : </b> The body tag in HTML is used to define the main content present inside an HTML page.
#             </li>
#             <br>
#             <li>
#                 <b> bold tag : </b> The bold tag in HTML is used to specify the bold text without any extra importance.
#             </li>
#             <br>
#             <li>
#                 <b> break tag : </b> The break tag inserts a single carriage return or breaks in the document. This element has no end tag.
#             </li>
#             <br>
#             <li>
#                 <b> button tag : </b> The button tag in HTML is used to define the clickable button. < button> tag is used to submit the content.
#             </li>
#             <br>
#             <li>
#                 <b>div tag : </b>  div tag defines division or section in an HTML document. The div tag is used as container for html elemnts and it is block element.
#             </li>
#             <br>
#             <li>
#                 <b> delete tag : </b> Delete tag is used to mark a portion of text which has been deleted from the document.
#             </li>
#             <br>
#             <li>
#                 <b> form tag : </b> This form is used basically for the registration process, logging into your profile on a website or creating your profile on a website, etc …
#             </li>
#             <br>
#             <li>
#                 <b> head tag : </b> The head tag in HTML is used to define the head portion of the document which contains information related to the document.
#             </li>
#             <br>
#             <li>
#                 <b>hr tag : </b> The hr tag in HTML stands for horizontal rule and is used to insert a horizontal rule.
#             </li>
#             <br>
#             <li>
#                 <b>html tag : </b> The html tag in HTML is used to define the root of HTML and XHTML documents.
#             </li>
#             <br>
#             <li>
#                 <b>image tag : </b> HTML Image tag helps to add the image in HTML.
#             </li>
#             <br>
#             <li>
#                 <b>input tag : </b> The input tag is used within < form> element to declare input controls that allow users to input data.
#             </li>
#             <br>
#             <li>
#                 <b>ins tag : </b> The ins tag is typically used to mark a range of text that has been added to the document.
#             </li>
#             <br>
#             <li>
#                 <b>itallic tag : </b> This tag is generally used to display a technical term, phrase, the important word in a different language.
#             </li>
#             <br>
#             <li>
#                 <b>list tag : </b> The list tag in HTML is used to define the list item in an HTML document. It is used within an Ordered List < ol> or Unordered List < ul>.
#             </li>
#             <br>
#             <li>
#                 <b>main tag : </b> The main tag is used to give the main information of a document. The content inside the < main> element should be unique for the document.
#             </li>
#             <br>
#             <li>
#                 <b>mark tag : </b> The mark tag in HTML is used to define the marked text. It is used to highlight the part of the text in a paragraph.
#             </li>
#             <br>
#             <li>
#                 <b>paragraph tag : </b> The < p> tag in HTML defines a paragraph. These have both opening and closing tags.
#             </li>
#             <br>
#             <li>
#                 <b>small tag : </b> The small tag in HTML is used to set small font sizes. It decreases the font size by one size
#             </li>
#             <br>
#             <li>
#                 <b>span tag : </b> This tag is an inline container used to mark up a part of text, or part of a document.
#             </li>
#             <br>
#             <li>
#                 <b>strong tag : </b> The strong tag in HTML is the parsed tag and is used to show the importance of the text. Make that text bold.
#             </li>
#             <br>
#             <li>
#                 <b>style tag : </b> The style tag in HTML helps us to design the web page.
#             </li>
#             <br>
#             <li>
#                 <b>table tag : </b> HTML Table is an arrangement of data in rows and columns
#             </li>
#             <br>
#             <li>
#                 <b>td tag : </b> The table data tag is used to define a standard cell in an HTML table.
#             </li>
#             <br>
#             <li>
#                 <b>th tag : </b> The table header tag in HTML is used to set the header cell of a table. Two types of cells in the HTML table Header & Standard.
#             </li>
#             <br>
#             <li>
#                 <b>title tag  : </b> The title tag in HTML is used to define the title of HTML document. It sets the title in the browser toolbar.
#             </li>
#             <br>
#             <li>
#                 <b>tr tag : </b> The table row tag is used to define a row in an HTML table. The < tr> element contains multiple < th> or < td> elements.
#             </li>
#             <br>
#             <li>
#                 <b>underline tag : </b> The underline tag in HTML stands for underline, and it’s used to underline the text enclosed within the < u> tag.
#             </li>
#             <br>
#             <li>
#                 <b>video tag : </b> HTML5 Video, along with knowing the different ways to add the videos to the HTML page.
#             </li>
#         </ol>
#     </div>
# </body>
# </html>

# %% [markdown]
# 5.  Create a description list of full stack web development tech stack, using the < dl> tag. Each term should be a tech stack name and each description should be a brief explanation of what the tech stack is used for.
#       - <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title></title>
# </head>
# <body>
#     <div>
#     <dl>
#         <dt>HTML</dt>
#         <dd>The standard markup language used to create the structure of web pages.</dd>
#
#         <dt>CSS</dt>
#         <dd>Stylesheet language used to design the look and layout of web pages.</dd>
#
#         <dt>JavaScript</dt>
#         <dd>A programming language used to add interactivity and dynamic behavior to web applications.</dd>
#
#         <dt>React.js</dt>
#         <dd>A JavaScript library for building user interfaces, commonly used for single-page applications.</dd>
#
#         <dt>Vue.js</dt>
#         <dd>A progressive JavaScript framework used for building user interfaces and single-page applications.</dd>
#
#         <dt>Angular</dt>
#         <dd>A TypeScript-based framework for building scalable and dynamic web applications.</dd>
#
#         <dt>Node.js</dt>
#         <dd>A runtime environment that allows JavaScript to be executed on the server side.</dd>
#
#         <dt>Express.js</dt>
#         <dd>A lightweight Node.js framework used for building web servers and APIs.</dd>
#
#         <dt>Next.js</dt>
#         <dd>A React framework that enables server-side rendering and static site generation.</dd>
#
#         <dt>NestJS</dt>
#         <dd>A TypeScript-based framework for building scalable and maintainable backend applications.</dd>
#
#         <dt>MongoDB</dt>
#         <dd>A NoSQL database that stores data in flexible, JSON-like documents.</dd>
#
#         <dt>PostgreSQL</dt>
#         <dd>A powerful, open-source relational database management system.</dd>
#
#         <dt>MySQL</dt>
#         <dd>A widely used relational database system for managing structured data.</dd>
#
#         <dt>Firebase</dt>
#         <dd>A Backend-as-a-Service (BaaS) that provides real-time database, authentication, and cloud functions.</dd>
#
#         <dt>GraphQL</dt>
#         <dd>A query language for APIs that allows clients to request only the data they need.</dd>
#
#         <dt>RESTful API</dt>
#         <dd>A web service design pattern that follows REST principles for building scalable APIs.</dd>
#
#         <dt>Docker</dt>
#         <dd>A platform for developing, shipping, and running applications in containers.</dd>
#
#         <dt>Kubernetes</dt>
#         <dd>An open-source system for automating the deployment and management of containerized applications.</dd>
#
#         <dt>Git</dt>
#         <dd>A version control system for tracking changes in source code during development.</dd>
#
#         <dt>GitHub</dt>
#         <dd>A code hosting platform for collaboration, version control, and repository management.</dd>
#
#         <dt>CI/CD (Continuous Integration/Continuous Deployment)</dt>
#         <dd>Practices and tools that automate code integration, testing, and deployment.</dd>
#     </dl>
#     </div>
# </body>
# </html>

# %% [markdown]
# 6. Create an ordered list of the full stack web development tech stack HTML, CSS, and JS. For each tech stack, create a table that lists the tech stack name, its primary use cases, and some key features or benefits. Below is a reference image.
#     - <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title></title>
# </head>
# <body>
#     <div>
#         <ol>
#             <li><h2>HTML</h2>
#                 <table border="" cellpadding="5">
#                     <tr>
#                         <th><b>Primary Use Cases</b></th>
#                         <th><b>Key Features/Benefits</b></th>
#                     </tr>
#                     <tr>
#                         <td>
#                             Building the structure of the web page
#                         </td>
#                         <td>
#                             <ul type="circle">
#                                 <li>simple and easy to learn</li>
#                                 <li>Compatible with all web browsers</li>
#                                 <li>Allows for semantic mark up</li>
#                             </ul>
#                         </td>
#                     </tr>
#                 </table>
#                 <li><h2>CSS</h2></li>
#                 <table border="" cellpadding="5">
#                     <tr>
#                         <th><b>Primary Use Cases</b></th>
#                         <th><b>Key Features/Benefits</b></th>
#                     </tr>
#                     <tr>
#                         <td>Styling and layout of web page</td>
#                         <td>
#                             <ul type="circle">
#                                 <li>Allows for seperation of content and presentation</li>
#                                 <li>Enables responsive design</li>
#                                 <li>Offers wide range of styling options</li>
#                             </ul>
#                         </td>
#                     </tr>
#                 </table>
#                 <li><h2>Java Script</h2></li>
#         <table border="" cellpadding="5">
#                     <tr>
#                         <th><b>Primary Use Cases</b></th>
#                         <th><b>Key Features/Benefits</b></th>
#                     </tr>
#                     <tr>
#                         <td>To make web pages interactive and dynamic</td>
#                         <td>
#                             <ul type="circle">
#                                 <li>Reduces load on the server</li>
#                                 <li>Extended Functionality</li>
#                                 <li>Speed</li>
#                                 <li>Rich Interface</li>
#                                 <li>Versatality</li>
#                             </ul>
#                         </td>
#                     </tr>
#                 </table>
#             </li>
#         </ol>
#     </div>
# </body>
# </html>

# %% [markdown]
# 7. Build a complex nested list structure representing a multi-level table of contents. Use unordered lists (< ul>) and list items (< li>) with inline-block styling to create a structured layout. Apply formatting tags to enhance the presentation of list items.
#     - The  table of contents are diplayed below
#     <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title></title>
# </head>
# <body>
#     <div>
#
#         <table style="border: 2px solid black;">
#             <tr>
#                 <td>
#                     <h1>Table of Contents</h1>
#                     <ul type="circle">
#                         <li><u style="color: blue;">Part 1 : Introduction</u></li>
#                         <li><u style="color: blue;">Part 2 : Getting Started</u></li>
#                         <li>
#                             <ul>
#                                 <li><u style="color: blue;">2.1 Installing the Software</u></li>
#                                 <li><u style="color: blue;">2.2 Creating a New Project</u></li>
#                                 <li>
#                                     <ul>
#                                         <li> <u style="color: blue;">2.2.1 Project Templates</u></li>
#                                         <li><u style="color: blue;">2.2.2 Customizing Settings</u></li>
#                                     </ul>
#                                 </li>
#                                 <li><u style="color: blue;">2.3 Exploring the Interface</u></li>
#                                 <li>
#                                     <ul>
#                                         <li><u style="color: blue;">2.3.1 Toolbar Features</u></li>
#                                         <li><u style="color: blue;">2.3.2 Panel Layout</u></li>
#                                         <li>
#                                             <ul>
#                                                 <li><u style="color: blue;">2.3.2.1 Docking Panels</u></li>
#                                                 <li><u style="color: blue;">2.3.2.2 Tabbed Interface</u></li>
#                                             </ul>
#                                         </li>
#                                     </ul>
#                                 </li>
#                             </ul>
#                         </li>
#                         <li><u style="color: blue;">Part 3 : Advanced Topics</u></li>
#                         <li>
#                             <ul>
#                                 <li><u style="color: blue;">3.1 Working with Plugins</u></li>
#                                 <li>
#                                     <ul>
#                                         <li><u style="color: blue;">3.1.1 Installing Plugins</u></li>
#                                         <li><u style="color: blue;">3.1.2 Plugin Configuration</u></li>
#                                     </ul>
#                                 </li>
#                                 <li><u style="color: blue;">3.2 Customizing the UI</u></li>
#                                 <li>
#                                     <ul>
#                                         <li><u style="color: blue;">3.2.1 Changing Themes</u></li>
#                                         <li><u style="color: blue;">3.2.2 Configuring Shortcuts</u></li>
#                                     </ul>
#                                 </li>
#                                 <li><u style="color: blue;">3.3 Optimizing Performance</u></li>
#                                 <li>
#                                     <ul>
#                                         <li><u style="color: blue;">3.3.1 Caching Strategies</u></li>
#                                         <li><u style="color: blue;">3.3.2 Resource Minification</u></li>
#                                     </ul>
#                                 </li>
#                             </ul>
#                         </li>
#                         <li><u style="color: blue;">Part 4 : Conclusion</u></li>
#                     </ul>
#                 </td>
#             </tr>
#         </table>
#     </div>
# </body>
# </html>
